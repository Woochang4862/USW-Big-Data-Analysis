# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import json
from sklearn.model_selection import StratifiedShuffleSplit, cross_val_score
from sklearn.preprocessing import StandardScaler

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.neural_network import MLPClassifier

train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

X = train_df.drop(['ID', 'target'], axis=1)
y = train_df['target']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)

models = {
    'Linear Discriminant Analysis': LinearDiscriminantAnalysis(),
    'Quadratic Discriminant Analysis': QuadraticDiscriminantAnalysis(),
    'Multi-Layer Perceptron': MLPClassifier(hidden_layer_sizes=(100, 50), max_iter=500, random_state=42)
}

for i, model_name in enumerate(models.keys(), 1):
    print(f"{i:2d}. {model_name}")

cv = StratifiedShuffleSplit(n_splits=10, test_size=0.2, random_state=42)

cv_results = {}
cv_scores_detail = {}

for model_name, model in models.items():
    print(f"{model_name}...", end=" ")
    
    if model_name in ['SVM (Linear)', 'SVM (RBF)', 'K-Nearest Neighbors', 
                      'Multi-Layer Perceptron', 
                      'Linear Discriminant Analysis', 'Quadratic Discriminant Analysis']:
        X_model = X_scaled
    else:
        X_model = X
    
    scores = cross_val_score(model, X_model, y, cv=cv, scoring='accuracy', n_jobs=-1)
    
    cv_results[model_name] = {
        'mean': scores.mean(),
        'std': scores.std(),
        'scores': scores
    }
    cv_scores_detail[model_name] = scores
    
    print(f"{scores.mean():.4f} ± {scores.std():.4f}")

results_df = pd.DataFrame({
    'Algorithm': list(cv_results.keys()),
    'Mean Accuracy': [cv_results[name]['mean'] for name in cv_results.keys()],
    'Std Deviation': [cv_results[name]['std'] for name in cv_results.keys()]
})

results_df = results_df.sort_values('Mean Accuracy', ascending=False).reset_index(drop=True)
results_df['Rank'] = results_df.index + 1

print("\n교차검증 결과:")
print(results_df.to_string(index=False))

print("\n결과 저장")
# 결과를 JSON 형식으로 저장
results_dict = {
    'cv_results': {
        model_name: {
            'mean': float(stats['mean']),
            'std': float(stats['std']),
            'scores': stats['scores'].tolist()
        } for model_name, stats in cv_results.items()
    },
    'rankings': results_df.to_dict('records')
}

# 결과 저장을 위한 디렉토리 생성
if not os.path.exists('results'):
    os.makedirs('results')

# JSON 파일로 저장
with open('results/cv_results.json', 'w', encoding='utf-8') as f:
    json.dump(results_dict, f, indent=4, ensure_ascii=False)

print("결과가 results/cv_results.json 파일에 저장되었습니다.")
# Out:
#  1. Linear Discriminant Analysis
#  2. Quadratic Discriminant Analysis
#  3. Multi-Layer Perceptron
# Linear Discriminant Analysis...
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /var/folders/10/l4f_yp1x1j50h0jqw1kpxpm80000gn/T/joblib_memmapping_folder_20504_a5f45c82b2814bb6807b33dbf6416c8a_75f02e2f1b4b4b6f9516a174622fe668 for automatic cleanup: unknown resource type folder
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /var/folders/10/l4f_yp1x1j50h0jqw1kpxpm80000gn/T/joblib_memmapping_folder_20504_663c916d7a324e44998309064900ef87_d3be989b06094ece96feeccedd37e576 for automatic cleanup: unknown resource type folder
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /var/folders/10/l4f_yp1x1j50h0jqw1kpxpm80000gn/T/joblib_memmapping_folder_20504_663c916d7a324e44998309064900ef87_d3be989b06094ece96feeccedd37e576/20504-4828880992-9648db5638bd45888879b7cfefd78286.pkl for automatic cleanup: unknown resource type file
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /var/folders/10/l4f_yp1x1j50h0jqw1kpxpm80000gn/T/joblib_memmapping_folder_20504_663c916d7a324e44998309064900ef87_d3be989b06094ece96feeccedd37e576/20504-4828880992-9648db5638bd45888879b7cfefd78286.pkl for automatic cleanup: unknown resource type file
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /var/folders/10/l4f_yp1x1j50h0jqw1kpxpm80000gn/T/joblib_memmapping_folder_20504_663c916d7a324e44998309064900ef87_d3be989b06094ece96feeccedd37e576/20504-4828880992-9648db5638bd45888879b7cfefd78286.pkl for automatic cleanup: unknown resource type file
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /var/folders/10/l4f_yp1x1j50h0jqw1kpxpm80000gn/T/joblib_memmapping_folder_20504_663c916d7a324e44998309064900ef87_d3be989b06094ece96feeccedd37e576/20504-4828880992-9648db5638bd45888879b7cfefd78286.pkl for automatic cleanup: unknown resource type file
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /var/folders/10/l4f_yp1x1j50h0jqw1kpxpm80000gn/T/joblib_memmapping_folder_20504_663c916d7a324e44998309064900ef87_d3be989b06094ece96feeccedd37e576/20504-4828880992-9648db5638bd45888879b7cfefd78286.pkl for automatic cleanup: unknown resource type file
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /var/folders/10/l4f_yp1x1j50h0jqw1kpxpm80000gn/T/joblib_memmapping_folder_20504_663c916d7a324e44998309064900ef87_d3be989b06094ece96feeccedd37e576/20504-4828880992-9648db5638bd45888879b7cfefd78286.pkl for automatic cleanup: unknown resource type file
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /var/folders/10/l4f_yp1x1j50h0jqw1kpxpm80000gn/T/joblib_memmapping_folder_20504_663c916d7a324e44998309064900ef87_d3be989b06094ece96feeccedd37e576/20504-4828880992-9648db5638bd45888879b7cfefd78286.pkl for automatic cleanup: unknown resource type file
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /var/folders/10/l4f_yp1x1j50h0jqw1kpxpm80000gn/T/joblib_memmapping_folder_20504_663c916d7a324e44998309064900ef87_d3be989b06094ece96feeccedd37e576/20504-4828880992-9648db5638bd45888879b7cfefd78286.pkl for automatic cleanup: unknown resource type file
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /var/folders/10/l4f_yp1x1j50h0jqw1kpxpm80000gn/T/joblib_memmapping_folder_20504_663c916d7a324e44998309064900ef87_d3be989b06094ece96feeccedd37e576/20504-4828880992-9648db5638bd45888879b7cfefd78286.pkl for automatic cleanup: unknown resource type file
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:591: RuntimeWarning: divide by zero encountered in matmul
#   self.xbar_ = self.priors_ @ self.means_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:591: RuntimeWarning: overflow encountered in matmul
#   self.xbar_ = self.priors_ @ self.means_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:591: RuntimeWarning: invalid value encountered in matmul
#   self.xbar_ = self.priors_ @ self.means_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:591: RuntimeWarning: divide by zero encountered in matmul
#   self.xbar_ = self.priors_ @ self.means_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:591: RuntimeWarning: overflow encountered in matmul
#   self.xbar_ = self.priors_ @ self.means_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:591: RuntimeWarning: invalid value encountered in matmul
#   self.xbar_ = self.priors_ @ self.means_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:591: RuntimeWarning: divide by zero encountered in matmul
#   self.xbar_ = self.priors_ @ self.means_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:591: RuntimeWarning: overflow encountered in matmul
#   self.xbar_ = self.priors_ @ self.means_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:591: RuntimeWarning: invalid value encountered in matmul
#   self.xbar_ = self.priors_ @ self.means_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:591: RuntimeWarning: divide by zero encountered in matmul
#   self.xbar_ = self.priors_ @ self.means_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:591: RuntimeWarning: overflow encountered in matmul
#   self.xbar_ = self.priors_ @ self.means_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:591: RuntimeWarning: invalid value encountered in matmul
#   self.xbar_ = self.priors_ @ self.means_
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /var/folders/10/l4f_yp1x1j50h0jqw1kpxpm80000gn/T/joblib_memmapping_folder_20504_663c916d7a324e44998309064900ef87_d3be989b06094ece96feeccedd37e576/20504-4828880992-9648db5638bd45888879b7cfefd78286.pkl for automatic cleanup: unknown resource type file
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:591: RuntimeWarning: divide by zero encountered in matmul
#   self.xbar_ = self.priors_ @ self.means_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:591: RuntimeWarning: overflow encountered in matmul
#   self.xbar_ = self.priors_ @ self.means_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:591: RuntimeWarning: invalid value encountered in matmul
#   self.xbar_ = self.priors_ @ self.means_
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /var/folders/10/l4f_yp1x1j50h0jqw1kpxpm80000gn/T/joblib_memmapping_folder_20504_663c916d7a324e44998309064900ef87_d3be989b06094ece96feeccedd37e576/20504-4828880992-9648db5638bd45888879b7cfefd78286.pkl for automatic cleanup: unknown resource type file
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:613: RuntimeWarning: divide by zero encountered in matmul
#   X = (
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:613: RuntimeWarning: overflow encountered in matmul
#   X = (
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:613: RuntimeWarning: invalid value encountered in matmul
#   X = (
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:629: RuntimeWarning: divide by zero encountered in matmul
#   self.scalings_ = scalings @ Vt.T[:, :rank]
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:629: RuntimeWarning: overflow encountered in matmul
#   self.scalings_ = scalings @ Vt.T[:, :rank]
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:629: RuntimeWarning: invalid value encountered in matmul
#   self.scalings_ = scalings @ Vt.T[:, :rank]
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:630: RuntimeWarning: divide by zero encountered in matmul
#   coef = (self.means_ - self.xbar_) @ self.scalings_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:630: RuntimeWarning: overflow encountered in matmul
#   coef = (self.means_ - self.xbar_) @ self.scalings_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:630: RuntimeWarning: invalid value encountered in matmul
#   coef = (self.means_ - self.xbar_) @ self.scalings_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:632: RuntimeWarning: divide by zero encountered in matmul
#   self.coef_ = coef @ self.scalings_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:632: RuntimeWarning: overflow encountered in matmul
#   self.coef_ = coef @ self.scalings_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:632: RuntimeWarning: invalid value encountered in matmul
#   self.coef_ = coef @ self.scalings_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:633: RuntimeWarning: divide by zero encountered in matmul
#   self.intercept_ -= self.xbar_ @ self.coef_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:633: RuntimeWarning: overflow encountered in matmul
#   self.intercept_ -= self.xbar_ @ self.coef_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:633: RuntimeWarning: invalid value encountered in matmul
#   self.intercept_ -= self.xbar_ @ self.coef_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:613: RuntimeWarning: divide by zero encountered in matmul
#   X = (
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:613: RuntimeWarning: overflow encountered in matmul
#   X = (
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:613: RuntimeWarning: invalid value encountered in matmul
#   X = (
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:613: RuntimeWarning: divide by zero encountered in matmul
#   X = (
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:613: RuntimeWarning: overflow encountered in matmul
#   X = (
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:613: RuntimeWarning: invalid value encountered in matmul
#   X = (
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:629: RuntimeWarning: divide by zero encountered in matmul
#   self.scalings_ = scalings @ Vt.T[:, :rank]
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:629: RuntimeWarning: overflow encountered in matmul
#   self.scalings_ = scalings @ Vt.T[:, :rank]
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:629: RuntimeWarning: invalid value encountered in matmul
#   self.scalings_ = scalings @ Vt.T[:, :rank]
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:630: RuntimeWarning: divide by zero encountered in matmul
#   coef = (self.means_ - self.xbar_) @ self.scalings_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:630: RuntimeWarning: overflow encountered in matmul
#   coef = (self.means_ - self.xbar_) @ self.scalings_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:630: RuntimeWarning: invalid value encountered in matmul
#   coef = (self.means_ - self.xbar_) @ self.scalings_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:632: RuntimeWarning: divide by zero encountered in matmul
#   self.coef_ = coef @ self.scalings_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:632: RuntimeWarning: overflow encountered in matmul
#   self.coef_ = coef @ self.scalings_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:632: RuntimeWarning: invalid value encountered in matmul
#   self.coef_ = coef @ self.scalings_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:633: RuntimeWarning: divide by zero encountered in matmul
#   self.intercept_ -= self.xbar_ @ self.coef_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:633: RuntimeWarning: overflow encountered in matmul
#   self.intercept_ -= self.xbar_ @ self.coef_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:633: RuntimeWarning: invalid value encountered in matmul
#   self.intercept_ -= self.xbar_ @ self.coef_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:629: RuntimeWarning: divide by zero encountered in matmul
#   self.scalings_ = scalings @ Vt.T[:, :rank]
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:629: RuntimeWarning: overflow encountered in matmul
#   self.scalings_ = scalings @ Vt.T[:, :rank]
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:629: RuntimeWarning: invalid value encountered in matmul
#   self.scalings_ = scalings @ Vt.T[:, :rank]
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:630: RuntimeWarning: divide by zero encountered in matmul
#   coef = (self.means_ - self.xbar_) @ self.scalings_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:630: RuntimeWarning: overflow encountered in matmul
#   coef = (self.means_ - self.xbar_) @ self.scalings_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:630: RuntimeWarning: invalid value encountered in matmul
#   coef = (self.means_ - self.xbar_) @ self.scalings_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:632: RuntimeWarning: divide by zero encountered in matmul
#   self.coef_ = coef @ self.scalings_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:632: RuntimeWarning: overflow encountered in matmul
#   self.coef_ = coef @ self.scalings_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:632: RuntimeWarning: invalid value encountered in matmul
#   self.coef_ = coef @ self.scalings_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:633: RuntimeWarning: divide by zero encountered in matmul
#   self.intercept_ -= self.xbar_ @ self.coef_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:633: RuntimeWarning: overflow encountered in matmul
#   self.intercept_ -= self.xbar_ @ self.coef_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:633: RuntimeWarning: invalid value encountered in matmul
#   self.intercept_ -= self.xbar_ @ self.coef_.T
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /var/folders/10/l4f_yp1x1j50h0jqw1kpxpm80000gn/T/joblib_memmapping_folder_20504_663c916d7a324e44998309064900ef87_d3be989b06094ece96feeccedd37e576/20504-4828880992-9648db5638bd45888879b7cfefd78286.pkl for automatic cleanup: unknown resource type file
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:613: RuntimeWarning: divide by zero encountered in matmul
#   X = (
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:613: RuntimeWarning: overflow encountered in matmul
#   X = (
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:613: RuntimeWarning: invalid value encountered in matmul
#   X = (
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:629: RuntimeWarning: divide by zero encountered in matmul
#   self.scalings_ = scalings @ Vt.T[:, :rank]
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:629: RuntimeWarning: overflow encountered in matmul
#   self.scalings_ = scalings @ Vt.T[:, :rank]
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:629: RuntimeWarning: invalid value encountered in matmul
#   self.scalings_ = scalings @ Vt.T[:, :rank]
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:630: RuntimeWarning: divide by zero encountered in matmul
#   coef = (self.means_ - self.xbar_) @ self.scalings_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:630: RuntimeWarning: overflow encountered in matmul
#   coef = (self.means_ - self.xbar_) @ self.scalings_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:630: RuntimeWarning: invalid value encountered in matmul
#   coef = (self.means_ - self.xbar_) @ self.scalings_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:632: RuntimeWarning: divide by zero encountered in matmul
#   self.coef_ = coef @ self.scalings_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:632: RuntimeWarning: overflow encountered in matmul
#   self.coef_ = coef @ self.scalings_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:632: RuntimeWarning: invalid value encountered in matmul
#   self.coef_ = coef @ self.scalings_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:633: RuntimeWarning: divide by zero encountered in matmul
#   self.intercept_ -= self.xbar_ @ self.coef_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:633: RuntimeWarning: overflow encountered in matmul
#   self.intercept_ -= self.xbar_ @ self.coef_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:633: RuntimeWarning: invalid value encountered in matmul
#   self.intercept_ -= self.xbar_ @ self.coef_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /var/folders/10/l4f_yp1x1j50h0jqw1kpxpm80000gn/T/joblib_memmapping_folder_20504_663c916d7a324e44998309064900ef87_d3be989b06094ece96feeccedd37e576/20504-4828880992-9648db5638bd45888879b7cfefd78286.pkl for automatic cleanup: unknown resource type file
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /var/folders/10/l4f_yp1x1j50h0jqw1kpxpm80000gn/T/joblib_memmapping_folder_20504_663c916d7a324e44998309064900ef87_d3be989b06094ece96feeccedd37e576/20504-4828880992-9648db5638bd45888879b7cfefd78286.pkl for automatic cleanup: unknown resource type file
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /var/folders/10/l4f_yp1x1j50h0jqw1kpxpm80000gn/T/joblib_memmapping_folder_20504_663c916d7a324e44998309064900ef87_d3be989b06094ece96feeccedd37e576/20504-4828880992-9648db5638bd45888879b7cfefd78286.pkl for automatic cleanup: unknown resource type file
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:613: RuntimeWarning: divide by zero encountered in matmul
#   X = (
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:613: RuntimeWarning: overflow encountered in matmul
#   X = (
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:613: RuntimeWarning: invalid value encountered in matmul
#   X = (
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:629: RuntimeWarning: divide by zero encountered in matmul
#   self.scalings_ = scalings @ Vt.T[:, :rank]
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:629: RuntimeWarning: overflow encountered in matmul
#   self.scalings_ = scalings @ Vt.T[:, :rank]
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:629: RuntimeWarning: invalid value encountered in matmul
#   self.scalings_ = scalings @ Vt.T[:, :rank]
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:630: RuntimeWarning: divide by zero encountered in matmul
#   coef = (self.means_ - self.xbar_) @ self.scalings_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:630: RuntimeWarning: overflow encountered in matmul
#   coef = (self.means_ - self.xbar_) @ self.scalings_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:630: RuntimeWarning: invalid value encountered in matmul
#   coef = (self.means_ - self.xbar_) @ self.scalings_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:632: RuntimeWarning: divide by zero encountered in matmul
#   self.coef_ = coef @ self.scalings_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:632: RuntimeWarning: overflow encountered in matmul
#   self.coef_ = coef @ self.scalings_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:632: RuntimeWarning: invalid value encountered in matmul
#   self.coef_ = coef @ self.scalings_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:633: RuntimeWarning: divide by zero encountered in matmul
#   self.intercept_ -= self.xbar_ @ self.coef_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:633: RuntimeWarning: overflow encountered in matmul
#   self.intercept_ -= self.xbar_ @ self.coef_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:633: RuntimeWarning: invalid value encountered in matmul
#   self.intercept_ -= self.xbar_ @ self.coef_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /var/folders/10/l4f_yp1x1j50h0jqw1kpxpm80000gn/T/joblib_memmapping_folder_20504_663c916d7a324e44998309064900ef87_d3be989b06094ece96feeccedd37e576/20504-4828880992-9648db5638bd45888879b7cfefd78286.pkl for automatic cleanup: unknown resource type file
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:591: RuntimeWarning: divide by zero encountered in matmul
#   self.xbar_ = self.priors_ @ self.means_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:591: RuntimeWarning: overflow encountered in matmul
#   self.xbar_ = self.priors_ @ self.means_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:591: RuntimeWarning: invalid value encountered in matmul
#   self.xbar_ = self.priors_ @ self.means_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:591: RuntimeWarning: divide by zero encountered in matmul
#   self.xbar_ = self.priors_ @ self.means_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:591: RuntimeWarning: overflow encountered in matmul
#   self.xbar_ = self.priors_ @ self.means_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:591: RuntimeWarning: invalid value encountered in matmul
#   self.xbar_ = self.priors_ @ self.means_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:591: RuntimeWarning: divide by zero encountered in matmul
#   self.xbar_ = self.priors_ @ self.means_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:591: RuntimeWarning: overflow encountered in matmul
#   self.xbar_ = self.priors_ @ self.means_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:591: RuntimeWarning: invalid value encountered in matmul
#   self.xbar_ = self.priors_ @ self.means_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:591: RuntimeWarning: divide by zero encountered in matmul
#   self.xbar_ = self.priors_ @ self.means_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:591: RuntimeWarning: overflow encountered in matmul
#   self.xbar_ = self.priors_ @ self.means_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:591: RuntimeWarning: invalid value encountered in matmul
#   self.xbar_ = self.priors_ @ self.means_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:591: RuntimeWarning: divide by zero encountered in matmul
#   self.xbar_ = self.priors_ @ self.means_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:591: RuntimeWarning: overflow encountered in matmul
#   self.xbar_ = self.priors_ @ self.means_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:591: RuntimeWarning: invalid value encountered in matmul
#   self.xbar_ = self.priors_ @ self.means_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:613: RuntimeWarning: divide by zero encountered in matmul
#   X = (
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:613: RuntimeWarning: overflow encountered in matmul
#   X = (
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:613: RuntimeWarning: invalid value encountered in matmul
#   X = (
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:629: RuntimeWarning: divide by zero encountered in matmul
#   self.scalings_ = scalings @ Vt.T[:, :rank]
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:629: RuntimeWarning: overflow encountered in matmul
#   self.scalings_ = scalings @ Vt.T[:, :rank]
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:629: RuntimeWarning: invalid value encountered in matmul
#   self.scalings_ = scalings @ Vt.T[:, :rank]
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:630: RuntimeWarning: divide by zero encountered in matmul
#   coef = (self.means_ - self.xbar_) @ self.scalings_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:630: RuntimeWarning: overflow encountered in matmul
#   coef = (self.means_ - self.xbar_) @ self.scalings_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:630: RuntimeWarning: invalid value encountered in matmul
#   coef = (self.means_ - self.xbar_) @ self.scalings_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:632: RuntimeWarning: divide by zero encountered in matmul
#   self.coef_ = coef @ self.scalings_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:632: RuntimeWarning: overflow encountered in matmul
#   self.coef_ = coef @ self.scalings_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:632: RuntimeWarning: invalid value encountered in matmul
#   self.coef_ = coef @ self.scalings_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:633: RuntimeWarning: divide by zero encountered in matmul
#   self.intercept_ -= self.xbar_ @ self.coef_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:633: RuntimeWarning: overflow encountered in matmul
#   self.intercept_ -= self.xbar_ @ self.coef_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:633: RuntimeWarning: invalid value encountered in matmul
#   self.intercept_ -= self.xbar_ @ self.coef_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /var/folders/10/l4f_yp1x1j50h0jqw1kpxpm80000gn/T/joblib_memmapping_folder_20504_663c916d7a324e44998309064900ef87_d3be989b06094ece96feeccedd37e576/20504-4828880992-9648db5638bd45888879b7cfefd78286.pkl for automatic cleanup: unknown resource type file
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:613: RuntimeWarning: divide by zero encountered in matmul
#   X = (
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:613: RuntimeWarning: overflow encountered in matmul
#   X = (
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:613: RuntimeWarning: invalid value encountered in matmul
#   X = (
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:629: RuntimeWarning: divide by zero encountered in matmul
#   self.scalings_ = scalings @ Vt.T[:, :rank]
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:629: RuntimeWarning: overflow encountered in matmul
#   self.scalings_ = scalings @ Vt.T[:, :rank]
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:629: RuntimeWarning: invalid value encountered in matmul
#   self.scalings_ = scalings @ Vt.T[:, :rank]
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:630: RuntimeWarning: divide by zero encountered in matmul
#   coef = (self.means_ - self.xbar_) @ self.scalings_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:630: RuntimeWarning: overflow encountered in matmul
#   coef = (self.means_ - self.xbar_) @ self.scalings_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:630: RuntimeWarning: invalid value encountered in matmul
#   coef = (self.means_ - self.xbar_) @ self.scalings_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:632: RuntimeWarning: divide by zero encountered in matmul
#   self.coef_ = coef @ self.scalings_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:632: RuntimeWarning: overflow encountered in matmul
#   self.coef_ = coef @ self.scalings_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:632: RuntimeWarning: invalid value encountered in matmul
#   self.coef_ = coef @ self.scalings_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:633: RuntimeWarning: divide by zero encountered in matmul
#   self.intercept_ -= self.xbar_ @ self.coef_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:633: RuntimeWarning: overflow encountered in matmul
#   self.intercept_ -= self.xbar_ @ self.coef_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:633: RuntimeWarning: invalid value encountered in matmul
#   self.intercept_ -= self.xbar_ @ self.coef_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /var/folders/10/l4f_yp1x1j50h0jqw1kpxpm80000gn/T/joblib_memmapping_folder_20504_663c916d7a324e44998309064900ef87_d3be989b06094ece96feeccedd37e576/20504-4828880992-9648db5638bd45888879b7cfefd78286.pkl for automatic cleanup: unknown resource type file
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:613: RuntimeWarning: divide by zero encountered in matmul
#   X = (
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:613: RuntimeWarning: overflow encountered in matmul
#   X = (
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:613: RuntimeWarning: invalid value encountered in matmul
#   X = (
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:629: RuntimeWarning: divide by zero encountered in matmul
#   self.scalings_ = scalings @ Vt.T[:, :rank]
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:629: RuntimeWarning: overflow encountered in matmul
#   self.scalings_ = scalings @ Vt.T[:, :rank]
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:629: RuntimeWarning: invalid value encountered in matmul
#   self.scalings_ = scalings @ Vt.T[:, :rank]
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:630: RuntimeWarning: divide by zero encountered in matmul
#   coef = (self.means_ - self.xbar_) @ self.scalings_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:630: RuntimeWarning: overflow encountered in matmul
#   coef = (self.means_ - self.xbar_) @ self.scalings_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:630: RuntimeWarning: invalid value encountered in matmul
#   coef = (self.means_ - self.xbar_) @ self.scalings_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:632: RuntimeWarning: divide by zero encountered in matmul
#   self.coef_ = coef @ self.scalings_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:632: RuntimeWarning: overflow encountered in matmul
#   self.coef_ = coef @ self.scalings_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:632: RuntimeWarning: invalid value encountered in matmul
#   self.coef_ = coef @ self.scalings_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:633: RuntimeWarning: divide by zero encountered in matmul
#   self.intercept_ -= self.xbar_ @ self.coef_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:633: RuntimeWarning: overflow encountered in matmul
#   self.intercept_ -= self.xbar_ @ self.coef_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:633: RuntimeWarning: invalid value encountered in matmul
#   self.intercept_ -= self.xbar_ @ self.coef_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /var/folders/10/l4f_yp1x1j50h0jqw1kpxpm80000gn/T/joblib_memmapping_folder_20504_663c916d7a324e44998309064900ef87_d3be989b06094ece96feeccedd37e576/20504-4828880992-9648db5638bd45888879b7cfefd78286.pkl for automatic cleanup: unknown resource type file
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:613: RuntimeWarning: divide by zero encountered in matmul
#   X = (
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:613: RuntimeWarning: overflow encountered in matmul
#   X = (
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:613: RuntimeWarning: invalid value encountered in matmul
#   X = (
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:629: RuntimeWarning: divide by zero encountered in matmul
#   self.scalings_ = scalings @ Vt.T[:, :rank]
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:629: RuntimeWarning: overflow encountered in matmul
#   self.scalings_ = scalings @ Vt.T[:, :rank]
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:629: RuntimeWarning: invalid value encountered in matmul
#   self.scalings_ = scalings @ Vt.T[:, :rank]
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:630: RuntimeWarning: divide by zero encountered in matmul
#   coef = (self.means_ - self.xbar_) @ self.scalings_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:630: RuntimeWarning: overflow encountered in matmul
#   coef = (self.means_ - self.xbar_) @ self.scalings_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:630: RuntimeWarning: invalid value encountered in matmul
#   coef = (self.means_ - self.xbar_) @ self.scalings_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:632: RuntimeWarning: divide by zero encountered in matmul
#   self.coef_ = coef @ self.scalings_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:632: RuntimeWarning: overflow encountered in matmul
#   self.coef_ = coef @ self.scalings_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:632: RuntimeWarning: invalid value encountered in matmul
#   self.coef_ = coef @ self.scalings_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:633: RuntimeWarning: divide by zero encountered in matmul
#   self.intercept_ -= self.xbar_ @ self.coef_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:633: RuntimeWarning: overflow encountered in matmul
#   self.intercept_ -= self.xbar_ @ self.coef_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:633: RuntimeWarning: invalid value encountered in matmul
#   self.intercept_ -= self.xbar_ @ self.coef_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /var/folders/10/l4f_yp1x1j50h0jqw1kpxpm80000gn/T/joblib_memmapping_folder_20504_663c916d7a324e44998309064900ef87_d3be989b06094ece96feeccedd37e576/20504-4828880992-9648db5638bd45888879b7cfefd78286.pkl for automatic cleanup: unknown resource type file
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:613: RuntimeWarning: divide by zero encountered in matmul
#   X = (
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:613: RuntimeWarning: overflow encountered in matmul
#   X = (
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:613: RuntimeWarning: invalid value encountered in matmul
#   X = (
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:629: RuntimeWarning: divide by zero encountered in matmul
#   self.scalings_ = scalings @ Vt.T[:, :rank]
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:629: RuntimeWarning: overflow encountered in matmul
#   self.scalings_ = scalings @ Vt.T[:, :rank]
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:629: RuntimeWarning: invalid value encountered in matmul
#   self.scalings_ = scalings @ Vt.T[:, :rank]
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:630: RuntimeWarning: divide by zero encountered in matmul
#   coef = (self.means_ - self.xbar_) @ self.scalings_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:630: RuntimeWarning: overflow encountered in matmul
#   coef = (self.means_ - self.xbar_) @ self.scalings_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:630: RuntimeWarning: invalid value encountered in matmul
#   coef = (self.means_ - self.xbar_) @ self.scalings_
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:632: RuntimeWarning: divide by zero encountered in matmul
#   self.coef_ = coef @ self.scalings_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:632: RuntimeWarning: overflow encountered in matmul
#   self.coef_ = coef @ self.scalings_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:632: RuntimeWarning: invalid value encountered in matmul
#   self.coef_ = coef @ self.scalings_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:633: RuntimeWarning: divide by zero encountered in matmul
#   self.intercept_ -= self.xbar_ @ self.coef_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:633: RuntimeWarning: overflow encountered in matmul
#   self.intercept_ -= self.xbar_ @ self.coef_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/discriminant_analysis.py:633: RuntimeWarning: invalid value encountered in matmul
#   self.intercept_ -= self.xbar_ @ self.coef_.T
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# ...
#   ret = a @ b
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /var/folders/10/l4f_yp1x1j50h0jqw1kpxpm80000gn/T/joblib_memmapping_folder_20504_663c916d7a324e44998309064900ef87_cfe227c0c042496db01093b3da7300a3/20504-4828880992-9648db5638bd45888879b7cfefd78286.pkl for automatic cleanup: unknown resource type file
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /var/folders/10/l4f_yp1x1j50h0jqw1kpxpm80000gn/T/joblib_memmapping_folder_20504_663c916d7a324e44998309064900ef87_cfe227c0c042496db01093b3da7300a3/20504-4828880992-9648db5638bd45888879b7cfefd78286.pkl for automatic cleanup: unknown resource type file
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /var/folders/10/l4f_yp1x1j50h0jqw1kpxpm80000gn/T/joblib_memmapping_folder_20504_663c916d7a324e44998309064900ef87_cfe227c0c042496db01093b3da7300a3/20504-4828880992-9648db5638bd45888879b7cfefd78286.pkl for automatic cleanup: unknown resource type file
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /var/folders/10/l4f_yp1x1j50h0jqw1kpxpm80000gn/T/joblib_memmapping_folder_20504_663c916d7a324e44998309064900ef87_cfe227c0c042496db01093b3da7300a3/20504-4828880992-9648db5638bd45888879b7cfefd78286.pkl for automatic cleanup: unknown resource type file
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /var/folders/10/l4f_yp1x1j50h0jqw1kpxpm80000gn/T/joblib_memmapping_folder_20504_663c916d7a324e44998309064900ef87_cfe227c0c042496db01093b3da7300a3/20504-4828880992-9648db5638bd45888879b7cfefd78286.pkl for automatic cleanup: unknown resource type file
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /var/folders/10/l4f_yp1x1j50h0jqw1kpxpm80000gn/T/joblib_memmapping_folder_20504_663c916d7a324e44998309064900ef87_cfe227c0c042496db01093b3da7300a3/20504-4828880992-9648db5638bd45888879b7cfefd78286.pkl for automatic cleanup: unknown resource type file
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /var/folders/10/l4f_yp1x1j50h0jqw1kpxpm80000gn/T/joblib_memmapping_folder_20504_663c916d7a324e44998309064900ef87_cfe227c0c042496db01093b3da7300a3/20504-4828880992-9648db5638bd45888879b7cfefd78286.pkl for automatic cleanup: unknown resource type file
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /var/folders/10/l4f_yp1x1j50h0jqw1kpxpm80000gn/T/joblib_memmapping_folder_20504_663c916d7a324e44998309064900ef87_cfe227c0c042496db01093b3da7300a3/20504-4828880992-9648db5638bd45888879b7cfefd78286.pkl for automatic cleanup: unknown resource type file
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /var/folders/10/l4f_yp1x1j50h0jqw1kpxpm80000gn/T/joblib_memmapping_folder_20504_663c916d7a324e44998309064900ef87_cfe227c0c042496db01093b3da7300a3/20504-4828880992-9648db5638bd45888879b7cfefd78286.pkl for automatic cleanup: unknown resource type file
# /opt/homebrew/lib/python3.13/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/homebrew/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /var/folders/10/l4f_yp1x1j50h0jqw1kpxpm80000gn/T/joblib_memmapping_folder_20504_663c916d7a324e44998309064900ef87_cfe227c0c042496db01093b3da7300a3/20504-4828880992-9648db5638bd45888879b7cfefd78286.pkl for automatic cleanup: unknown resource type file
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /var/folders/10/l4f_yp1x1j50h0jqw1kpxpm80000gn/T/joblib_memmapping_folder_20504_663c916d7a324e44998309064900ef87_cfe227c0c042496db01093b3da7300a3/20504-4828880992-9648db5638bd45888879b7cfefd78286.pkl for automatic cleanup: unknown resource type file
# 0.8289 ± 0.0033
#
# 교차검증 결과:
#                       Algorithm  Mean Accuracy  Std Deviation  Rank
# Quadratic Discriminant Analysis       0.877714       0.004455     1
#          Multi-Layer Perceptron       0.828901       0.003327     2
#    Linear Discriminant Analysis       0.483222       0.007222     3
#
# 결과 저장
# 결과가 results/cv_results.json 파일에 저장되었습니다.
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /loky-20504-7x3ikvvn for automatic cleanup: unknown resource type semlock
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /loky-20504-1wcd4tcr for automatic cleanup: unknown resource type semlock
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /loky-20504-y3mion1a for automatic cleanup: unknown resource type semlock
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /loky-20504-38ypld4z for automatic cleanup: unknown resource type semlock
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /loky-20504-s0_p68c0 for automatic cleanup: unknown resource type semlock
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /loky-20504-tn4xx2dc for automatic cleanup: unknown resource type semlock
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /loky-20504-1fls0zac for automatic cleanup: unknown resource type semlock
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /loky-20504-2a0s1rrv for automatic cleanup: unknown resource type semlock
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /loky-20504-vj4bmqyz for automatic cleanup: unknown resource type semlock
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /loky-20504-e0zbkdx7 for automatic cleanup: unknown resource type semlock
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /loky-20504-4d141ugf for automatic cleanup: unknown resource type semlock
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /loky-20504-0olmiuqy for automatic cleanup: unknown resource type semlock
